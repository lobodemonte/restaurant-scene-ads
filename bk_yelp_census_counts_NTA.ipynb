# %% [markdown]
# This notebook takes the merged Yelp and Census Tract data frame and calculates the frequency of restaurant counts for each price range (including those Missing) for each Census tract.
# Using GEOID (census tract identifier), I merged household income distribution data for each census tract (in percentages), then calculate the actual number of households for each income range.

# %%
# Setting up modules
import geopandas as gpd
from geopandas import GeoDataFrame
import numpy as np
import pandas as pd
from shapely.geometry import Point
import matplotlib.pylab as plt

# Data path 
path = '/Users/andrewnorris/restaurant-scene-ads/'

# %%
bk = gpd.read_file('/Users/andrewnorris/restaurant-scene-ads/data/Yelp/BK/BK_Yelp_CensusTract_NTA.shp')
bk.head()
# Out:
#                        id                   alias         name  is_closed  \
# 0  6gzQLjzJk25ePm_JS7ZAug         esme-brooklyn-2         Esme          0
# 1  Swjm9no7DRqhThLlf0EHng  sama-street-brooklyn-2  Sama Street          0
# 2  utM-5navObsVA5sCRHobzA        madre-brooklyn-2        Madre          0
# 3  L9SuMN3UsGipopWOe3pr9w        chiko-brooklyn-2        Chiko          0
# 4  vyKBwzRdNX4yiJDIFv37iw      oxomoco-brooklyn-2      Oxomoco          0
#
#    review_cou  rating    price                             categories  \
# 0         328     4.5       $$               newamerican|cocktailbars
# 1          58     4.5       $$  cocktailbars|panasian|tapasmallplates
# 2          38     5.0  MISSING                            newamerican
# 3          36     5.0  MISSING                         japanese|sushi
# 4         247     4.0      $$$                                mexican
#
#     latitude  longitude  ...     NTAName Households    0-25k   25k-50k  \
# 0  40.733203 -73.954967  ...  Greenpoint      16223  0.20021  0.136843
# 1  40.732870 -73.954480  ...  Greenpoint      16223  0.20021  0.136843
# 2  40.733110 -73.957980  ...  Greenpoint      16223  0.20021  0.136843
# 3  40.731900 -73.954220  ...  Greenpoint      16223  0.20021  0.136843
# 4  40.729910 -73.955480  ...  Greenpoint      16223  0.20021  0.136843
#
#     50k-75k  75k-100k 100k-125k 125k-150k    > 150k  \
# 0  0.151883   0.13598  0.105529  0.086914  0.182642
# 1  0.151883   0.13598  0.105529  0.086914  0.182642
# 2  0.151883   0.13598  0.105529  0.086914  0.182642
# 3  0.151883   0.13598  0.105529  0.086914  0.182642
# 4  0.151883   0.13598  0.105529  0.086914  0.182642
#
#                      geometry
# 0  POINT (-73.95497 40.73320)
# 1  POINT (-73.95448 40.73287)
# 2  POINT (-73.95798 40.73311)
# 3  POINT (-73.95422 40.73190)
# 4  POINT (-73.95548 40.72991)
#
# [5 rows x 27 columns]

# %%
bk = pd.DataFrame(bk)

# %%
bk.columns
# Out:
# Index(['id', 'alias', 'name', 'is_closed', 'review_cou', 'rating', 'price',
#        'categories', 'latitude', 'longitude', 'address', 'city', 'zipcode',
#        'state', 'country', 'index_righ', 'NTACode', 'NTAName', 'Households',
#        '0-25k', '25k-50k', '50k-75k', '75k-100k', '100k-125k', '125k-150k',
#        '> 150k', 'geometry'],
#       dtype='object')

# %%
bkcounts = pd.DataFrame(bk.groupby(['NTACode', 'price'])['price'].count())

# %%
bkcounts.head(10)
# Out:
#                  price
# NTACode price
# BK09    $           29
#         $$          46
#         $$$          6
#         MISSING     16
# BK17    $           35
#         $$          54
#         $$$         10
#         $$$$         2
#         MISSING     21
# BK19    $           22

# %%
bkcounts = bkcounts.unstack(level='price', fill_value=0).reset_index()
bkcounts.head(10)
# Out:
#       NTACode price
# price             $  $$ $$$ $$$$ MISSING
# 0        BK09    29  46   6    0      16
# 1        BK17    35  54  10    2      21
# 2        BK19    22  17   4    1      14
# 3        BK21    24  12   0    0      14
# 4        BK23     6   4   2    0       4
# 5        BK25    29  41  10    1      24
# 6        BK26    17   3   0    0      12
# 7        BK27    16  22   1    0      14
# 8        BK28    79  49   1    0      50
# 9        BK29    42  29   1    1      31

# %%
bkcounts.columns = ['_'.join(col) for col in bkcounts.columns]
bkcounts.columns = ['NTACode','price_$', 'price_$$', 'price_$$$', 'price_$$$$','MISSING']
bkcounts.head(10)
# Out:
#   NTACode  price_$  price_$$  price_$$$  price_$$$$  MISSING
# 0    BK09       29        46          6           0       16
# 1    BK17       35        54         10           2       21
# 2    BK19       22        17          4           1       14
# 3    BK21       24        12          0           0       14
# 4    BK23        6         4          2           0        4
# 5    BK25       29        41         10           1       24
# 6    BK26       17         3          0           0       12
# 7    BK27       16        22          1           0       14
# 8    BK28       79        49          1           0       50
# 9    BK29       42        29          1           1       31

# %%
bkcounts.columns
# Out:
# Index(['NTACode', 'price_$', 'price_$$', 'price_$$$', 'price_$$$$', 'MISSING'], dtype='object')

# %%
bkcounts.NTACode.dtype
# Out:
# dtype('O')

# %%
#bkcounts['GEOID'] = bkcounts['GEOID'].astype(np.int64) #bkinc data frame GEOID is int64 type - change for merging

# %%
#bkinc = pd.read_csv(path+'BK_hh_income_dis_count.csv')

# %%
#bkinc.head()

# %%
#bkinc = bkinc.rename(columns={'ID':'GEOID'})

# %%
bk_price_inc = bkcounts.merge(bk, how='inner', on='NTACode')

# %%
bk_price_inc.head(10)
# Out:
#   NTACode  price_$  price_$$  price_$$$  price_$$$$  MISSING  \
# 0    BK09       29        46          6           0       16
# 1    BK09       29        46          6           0       16
# 2    BK09       29        46          6           0       16
# 3    BK09       29        46          6           0       16
# 4    BK09       29        46          6           0       16
# 5    BK09       29        46          6           0       16
# 6    BK09       29        46          6           0       16
# 7    BK09       29        46          6           0       16
# 8    BK09       29        46          6           0       16
# 9    BK09       29        46          6           0       16
#
#                        id                            alias  \
# 0  5Fz1WlY3lxy8gJFs8s_1Dw                the-binc-brooklyn
# 1  _N92SH1Zi-Hbxn_bNHFz0Q          noodle-pudding-brooklyn
# 2  j-a8HUcsBJXHV2IfF786jw    kogane-ramen-brooklyn-heights
# 3  xhuDOqY9G5mPuSqBnMCaYw            henrys-end-brooklyn-4
# 4  OwH9eXxsBeeYl8s7TXUBiA                san-blas-brooklyn
# 5  HcWm-9ZZu2_brnuRxN5Gpg               tutt-cafe-brooklyn
# 6  njKwUg6oYDEEtLuunTmgbg         heights-falafel-brooklyn
# 7  3OKf1QQnDhjkBKVg0eMllQ           sushi-gallery-brooklyn
# 8  lqkqsHe_2KN35LE5JIaYNg  henry-street-ale-house-brooklyn
# 9  wwgLgUlsM4qlSG3aA7o6Ig                b-good-brooklyn-3
#
#                      name  is_closed  ...                       NTAName  \
# 0                The Binc          0  ...  Brooklyn Heights-Cobble Hill
# 1          Noodle Pudding          0  ...  Brooklyn Heights-Cobble Hill
# 2            Kogane Ramen          0  ...  Brooklyn Heights-Cobble Hill
# 3             Henry's End          0  ...  Brooklyn Heights-Cobble Hill
# 4                San Blas          0  ...  Brooklyn Heights-Cobble Hill
# 5               Tutt Cafe          0  ...  Brooklyn Heights-Cobble Hill
# 6         Heights Falafel          0  ...  Brooklyn Heights-Cobble Hill
# 7           Sushi Gallery          0  ...  Brooklyn Heights-Cobble Hill
# 8  Henry Street Ale House          0  ...  Brooklyn Heights-Cobble Hill
# 9                  B.GOOD          0  ...  Brooklyn Heights-Cobble Hill
#
#    Households    0-25k   25k-50k   50k-75k  75k-100k 100k-125k 125k-150k  \
# 0       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 1       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 2       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 3       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 4       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 5       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 6       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 7       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 8       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
# 9       11115  0.11507  0.108052  0.069906  0.110751  0.093747  0.075574
#
#      > 150k                    geometry
# 0  0.426901  POINT (-73.99231 40.69927)
# 1  0.426901  POINT (-73.99203 40.69979)
# 2  0.426901  POINT (-73.99268 40.69861)
# 3  0.426901  POINT (-73.99257 40.69869)
# 4  0.426901  POINT (-73.99371 40.69452)
# 5  0.426901  POINT (-73.99322 40.70019)
# 6  0.426901  POINT (-73.99271 40.69855)
# 7  0.426901  POINT (-73.99337 40.69760)
# 8  0.426901  POINT (-73.99235 40.69911)
# 9  0.426901  POINT (-73.99366 40.69483)
#
# [10 rows x 32 columns]

# %%
bk_price_inc = bk_price_inc.rename(columns={"0-25k": "pct_0-25k", "25k-50k": "pct_25k-50k", '50k-75k':'pct_50k-75k', \
                                           '75k-100k':'pct_75k-100k', '100k-125k':'pct_100k-125k', '125k-150k':'pct_125k-150k',\
                                           '> 150k':'pct_> 150k'})

# %%
bk_price_inc['num_0-25k'] = bk_price_inc['Households']*bk_price_inc['pct_0-25k']
bk_price_inc['num_25k-50k'] = bk_price_inc['Households']*bk_price_inc['pct_25k-50k']
bk_price_inc['num_50k-75k'] = bk_price_inc['Households']*bk_price_inc['pct_50k-75k']
bk_price_inc['num_75k-100k'] = bk_price_inc['Households']*bk_price_inc['pct_75k-100k']
bk_price_inc['num_100k-125k'] = bk_price_inc['Households']*bk_price_inc['pct_100k-125k']
bk_price_inc['num_125k-150k'] = bk_price_inc['Households']*bk_price_inc['pct_125k-150k']
bk_price_inc['num_> 150k'] = bk_price_inc['Households']*bk_price_inc['pct_> 150k']

# %%
bk_price_inc.head()
# Out:
#   NTACode  price_$  price_$$  price_$$$  price_$$$$  MISSING  \
# 0    BK09       29        46          6           0       16
# 1    BK09       29        46          6           0       16
# 2    BK09       29        46          6           0       16
# 3    BK09       29        46          6           0       16
# 4    BK09       29        46          6           0       16
#
#                        id                          alias            name  \
# 0  5Fz1WlY3lxy8gJFs8s_1Dw              the-binc-brooklyn        The Binc
# 1  _N92SH1Zi-Hbxn_bNHFz0Q        noodle-pudding-brooklyn  Noodle Pudding
# 2  j-a8HUcsBJXHV2IfF786jw  kogane-ramen-brooklyn-heights    Kogane Ramen
# 3  xhuDOqY9G5mPuSqBnMCaYw          henrys-end-brooklyn-4     Henry's End
# 4  OwH9eXxsBeeYl8s7TXUBiA              san-blas-brooklyn        San Blas
#
#    is_closed  ...  pct_125k-150k  pct_> 150k                    geometry  \
# 0          0  ...       0.075574    0.426901  POINT (-73.99231 40.69927)
# 1          0  ...       0.075574    0.426901  POINT (-73.99203 40.69979)
# 2          0  ...       0.075574    0.426901  POINT (-73.99268 40.69861)
# 3          0  ...       0.075574    0.426901  POINT (-73.99257 40.69869)
# 4          0  ...       0.075574    0.426901  POINT (-73.99371 40.69452)
#
#   num_0-25k  num_25k-50k  num_50k-75k num_75k-100k num_100k-125k  \
# 0    1279.0       1201.0        777.0       1231.0        1042.0
# 1    1279.0       1201.0        777.0       1231.0        1042.0
# 2    1279.0       1201.0        777.0       1231.0        1042.0
# 3    1279.0       1201.0        777.0       1231.0        1042.0
# 4    1279.0       1201.0        777.0       1231.0        1042.0
#
#   num_125k-150k num_> 150k
# 0         840.0     4745.0
# 1         840.0     4745.0
# 2         840.0     4745.0
# 3         840.0     4745.0
# 4         840.0     4745.0
#
# [5 rows x 39 columns]

# %%
bk_price_inc = pd.DataFrame(bk_price_inc.groupby(['NTACode', 'price'])['price'].count())

# %%
bk_price_inc.shape
# Out:
# (205, 1)

# %%
bk_price_inc.head(10)
# Out:
#                  price
# NTACode price
# BK09    $           29
#         $$          46
#         $$$          6
#         MISSING     16
# BK17    $           35
#         $$          54
#         $$$         10
#         $$$$         2
#         MISSING     21
# BK19    $           22

# %%
bk_price_inc.to_csv('BK_incdist_pricefreq_NTA.csv')
