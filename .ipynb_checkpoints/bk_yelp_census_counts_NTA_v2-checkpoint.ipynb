# %% [markdown]
# This notebook takes the merged Yelp and Census Tract data frame and calculates the frequency of restaurant counts for each price range (including those Missing) for each Census tract.
# Using GEOID (census tract identifier), I merged household income distribution data for each census tract (in percentages), then calculate the actual number of households for each income range.

# %%
# Setting up modules
import geopandas as gpd
from geopandas import GeoDataFrame
import numpy as np
import pandas as pd
from shapely.geometry import Point
import matplotlib.pylab as plt

# Data path 
path = '/Users/andrewnorris/restaurant-scene-ads/'

# %%
bk = gpd.read_file('/Users/andrewnorris/restaurant-scene-ads/data/Yelp/BK/BK_Yelp_CensusTract_NTA.shp')
bk.head()
# Out:
#                        id                   alias         name  is_closed  \
# 0  6gzQLjzJk25ePm_JS7ZAug         esme-brooklyn-2         Esme          0
# 1  Swjm9no7DRqhThLlf0EHng  sama-street-brooklyn-2  Sama Street          0
# 2  utM-5navObsVA5sCRHobzA        madre-brooklyn-2        Madre          0
# 3  L9SuMN3UsGipopWOe3pr9w        chiko-brooklyn-2        Chiko          0
# 4  vyKBwzRdNX4yiJDIFv37iw      oxomoco-brooklyn-2      Oxomoco          0
#
#    review_cou  rating    price                             categories  \
# 0         328     4.5       $$               newamerican|cocktailbars
# 1          58     4.5       $$  cocktailbars|panasian|tapasmallplates
# 2          38     5.0  MISSING                            newamerican
# 3          36     5.0  MISSING                         japanese|sushi
# 4         247     4.0      $$$                                mexican
#
#     latitude  longitude  ...     NTAName Households    0-25k   25k-50k  \
# 0  40.733203 -73.954967  ...  Greenpoint      16223  0.20021  0.136843
# 1  40.732870 -73.954480  ...  Greenpoint      16223  0.20021  0.136843
# 2  40.733110 -73.957980  ...  Greenpoint      16223  0.20021  0.136843
# 3  40.731900 -73.954220  ...  Greenpoint      16223  0.20021  0.136843
# 4  40.729910 -73.955480  ...  Greenpoint      16223  0.20021  0.136843
#
#     50k-75k  75k-100k 100k-125k 125k-150k    > 150k  \
# 0  0.151883   0.13598  0.105529  0.086914  0.182642
# 1  0.151883   0.13598  0.105529  0.086914  0.182642
# 2  0.151883   0.13598  0.105529  0.086914  0.182642
# 3  0.151883   0.13598  0.105529  0.086914  0.182642
# 4  0.151883   0.13598  0.105529  0.086914  0.182642
#
#                      geometry
# 0  POINT (-73.95497 40.73320)
# 1  POINT (-73.95448 40.73287)
# 2  POINT (-73.95798 40.73311)
# 3  POINT (-73.95422 40.73190)
# 4  POINT (-73.95548 40.72991)
#
# [5 rows x 27 columns]

# %%
bk = pd.DataFrame(bk)

# %%
bk.columns
# Out:
# Index(['id', 'alias', 'name', 'is_closed', 'review_cou', 'rating', 'price',
#        'categories', 'latitude', 'longitude', 'address', 'city', 'zipcode',
#        'state', 'country', 'index_righ', 'NTACode', 'NTAName', 'Households',
#        '0-25k', '25k-50k', '50k-75k', '75k-100k', '100k-125k', '125k-150k',
#        '> 150k', 'geometry'],
#       dtype='object')

# %%
bkcounts = pd.DataFrame(bk.groupby(['NTACode', 'price'])['price'].count())
bkcounts.head(10)
# Out:
#                  price
# NTACode price
# BK09    $           29
#         $$          46
#         $$$          6
#         MISSING     16
# BK17    $           35
#         $$          54
#         $$$         10
#         $$$$         2
#         MISSING     21
# BK19    $           22

# %%
bkcounts = bkcounts.unstack(level='price', fill_value=0).reset_index()
bkcounts.head(10)
# Out:
#       NTACode price
# price             $  $$ $$$ $$$$ MISSING
# 0        BK09    29  46   6    0      16
# 1        BK17    35  54  10    2      21
# 2        BK19    22  17   4    1      14
# 3        BK21    24  12   0    0      14
# 4        BK23     6   4   2    0       4
# 5        BK25    29  41  10    1      24
# 6        BK26    17   3   0    0      12
# 7        BK27    16  22   1    0      14
# 8        BK28    79  49   1    0      50
# 9        BK29    42  29   1    1      31

# %%
bkcounts.columns = ['_'.join(col) for col in bkcounts.columns]
bkcounts.columns = ['NTACode','price_$', 'price_$$', 'price_$$$', 'price_$$$$','MISSING']
bkcounts.head(10)
# Out:
#   NTACode  price_$  price_$$  price_$$$  price_$$$$  MISSING
# 0    BK09       29        46          6           0       16
# 1    BK17       35        54         10           2       21
# 2    BK19       22        17          4           1       14
# 3    BK21       24        12          0           0       14
# 4    BK23        6         4          2           0        4
# 5    BK25       29        41         10           1       24
# 6    BK26       17         3          0           0       12
# 7    BK27       16        22          1           0       14
# 8    BK28       79        49          1           0       50
# 9    BK29       42        29          1           1       31

# %%
bkcounts['NTACode'].nunique()
# Out:
# 51

# %%
bk.head()
# Out:
#                        id                   alias         name  is_closed  \
# 0  6gzQLjzJk25ePm_JS7ZAug         esme-brooklyn-2         Esme          0
# 1  Swjm9no7DRqhThLlf0EHng  sama-street-brooklyn-2  Sama Street          0
# 2  utM-5navObsVA5sCRHobzA        madre-brooklyn-2        Madre          0
# 3  L9SuMN3UsGipopWOe3pr9w        chiko-brooklyn-2        Chiko          0
# 4  vyKBwzRdNX4yiJDIFv37iw      oxomoco-brooklyn-2      Oxomoco          0
#
#    review_cou  rating    price                             categories  \
# 0         328     4.5       $$               newamerican|cocktailbars
# 1          58     4.5       $$  cocktailbars|panasian|tapasmallplates
# 2          38     5.0  MISSING                            newamerican
# 3          36     5.0  MISSING                         japanese|sushi
# 4         247     4.0      $$$                                mexican
#
#     latitude  longitude  ...     NTAName Households    0-25k   25k-50k  \
# 0  40.733203 -73.954967  ...  Greenpoint      16223  0.20021  0.136843
# 1  40.732870 -73.954480  ...  Greenpoint      16223  0.20021  0.136843
# 2  40.733110 -73.957980  ...  Greenpoint      16223  0.20021  0.136843
# 3  40.731900 -73.954220  ...  Greenpoint      16223  0.20021  0.136843
# 4  40.729910 -73.955480  ...  Greenpoint      16223  0.20021  0.136843
#
#     50k-75k  75k-100k 100k-125k 125k-150k    > 150k  \
# 0  0.151883   0.13598  0.105529  0.086914  0.182642
# 1  0.151883   0.13598  0.105529  0.086914  0.182642
# 2  0.151883   0.13598  0.105529  0.086914  0.182642
# 3  0.151883   0.13598  0.105529  0.086914  0.182642
# 4  0.151883   0.13598  0.105529  0.086914  0.182642
#
#                      geometry
# 0  POINT (-73.95497 40.73320)
# 1  POINT (-73.95448 40.73287)
# 2  POINT (-73.95798 40.73311)
# 3  POINT (-73.95422 40.73190)
# 4  POINT (-73.95548 40.72991)
#
# [5 rows x 27 columns]

# %%
bk.columns
# Out:
# Index(['id', 'alias', 'name', 'is_closed', 'review_cou', 'rating', 'price',
#        'categories', 'latitude', 'longitude', 'address', 'city', 'zipcode',
#        'state', 'country', 'index_righ', 'NTACode', 'NTAName', 'Households',
#        '0-25k', '25k-50k', '50k-75k', '75k-100k', '100k-125k', '125k-150k',
#        '> 150k', 'geometry'],
#       dtype='object')

# %%
bk = bk.rename(columns={"0-25k": "pct_0-25k", "25k-50k": "pct_25k-50k", '50k-75k':'pct_50k-75k', \
                                           '75k-100k':'pct_75k-100k', '100k-125k':'pct_100k-125k', '125k-150k':'pct_125k-150k',\
                                           '> 150k':'pct_> 150k'})

# %%
bk['num_0-25k'] = bk['Households']*bk['pct_0-25k']
bk['num_25k-50k'] = bk['Households']*bk['pct_25k-50k']
bk['num_50k-75k'] = bk['Households']*bk['pct_50k-75k']
bk['num_75k-100k'] = bk['Households']*bk['pct_75k-100k']
bk['num_100k-125k'] = bk['Households']*bk['pct_100k-125k']
bk['num_125k-150k'] = bk['Households']*bk['pct_125k-150k']
bk['num_> 150k'] = bk['Households']*bk['pct_> 150k']
bk.head()
# Out:
#                        id                   alias         name  is_closed  \
# 0  6gzQLjzJk25ePm_JS7ZAug         esme-brooklyn-2         Esme          0
# 1  Swjm9no7DRqhThLlf0EHng  sama-street-brooklyn-2  Sama Street          0
# 2  utM-5navObsVA5sCRHobzA        madre-brooklyn-2        Madre          0
# 3  L9SuMN3UsGipopWOe3pr9w        chiko-brooklyn-2        Chiko          0
# 4  vyKBwzRdNX4yiJDIFv37iw      oxomoco-brooklyn-2      Oxomoco          0
#
#    review_cou  rating    price                             categories  \
# 0         328     4.5       $$               newamerican|cocktailbars
# 1          58     4.5       $$  cocktailbars|panasian|tapasmallplates
# 2          38     5.0  MISSING                            newamerican
# 3          36     5.0  MISSING                         japanese|sushi
# 4         247     4.0      $$$                                mexican
#
#     latitude  longitude  ... pct_125k-150k pct_> 150k  \
# 0  40.733203 -73.954967  ...      0.086914   0.182642
# 1  40.732870 -73.954480  ...      0.086914   0.182642
# 2  40.733110 -73.957980  ...      0.086914   0.182642
# 3  40.731900 -73.954220  ...      0.086914   0.182642
# 4  40.729910 -73.955480  ...      0.086914   0.182642
#
#                      geometry num_0-25k num_25k-50k  num_50k-75k num_75k-100k  \
# 0  POINT (-73.95497 40.73320)    3248.0      2220.0       2464.0       2206.0
# 1  POINT (-73.95448 40.73287)    3248.0      2220.0       2464.0       2206.0
# 2  POINT (-73.95798 40.73311)    3248.0      2220.0       2464.0       2206.0
# 3  POINT (-73.95422 40.73190)    3248.0      2220.0       2464.0       2206.0
# 4  POINT (-73.95548 40.72991)    3248.0      2220.0       2464.0       2206.0
#
#   num_100k-125k  num_125k-150k  num_> 150k
# 0        1712.0         1410.0      2963.0
# 1        1712.0         1410.0      2963.0
# 2        1712.0         1410.0      2963.0
# 3        1712.0         1410.0      2963.0
# 4        1712.0         1410.0      2963.0
#
# [5 rows x 34 columns]

# %%
bkntainc = bk[['NTACode','NTAName', 'Households', 'pct_0-25k',
       'pct_25k-50k', 'pct_50k-75k', 'pct_75k-100k', 'pct_100k-125k',
       'pct_125k-150k', 'pct_> 150k', 'geometry', 'num_0-25k', 'num_25k-50k',
       'num_50k-75k', 'num_75k-100k', 'num_100k-125k', 'num_125k-150k',
       'num_> 150k']].copy()
bkntainc.head()
# Out:
#   NTACode     NTAName  Households  pct_0-25k  pct_25k-50k  pct_50k-75k  \
# 0    BK76  Greenpoint       16223    0.20021     0.136843     0.151883
# 1    BK76  Greenpoint       16223    0.20021     0.136843     0.151883
# 2    BK76  Greenpoint       16223    0.20021     0.136843     0.151883
# 3    BK76  Greenpoint       16223    0.20021     0.136843     0.151883
# 4    BK76  Greenpoint       16223    0.20021     0.136843     0.151883
#
#    pct_75k-100k  pct_100k-125k  pct_125k-150k  pct_> 150k  \
# 0       0.13598       0.105529       0.086914    0.182642
# 1       0.13598       0.105529       0.086914    0.182642
# 2       0.13598       0.105529       0.086914    0.182642
# 3       0.13598       0.105529       0.086914    0.182642
# 4       0.13598       0.105529       0.086914    0.182642
#
#                      geometry  num_0-25k  num_25k-50k  num_50k-75k  \
# 0  POINT (-73.95497 40.73320)     3248.0       2220.0       2464.0
# 1  POINT (-73.95448 40.73287)     3248.0       2220.0       2464.0
# 2  POINT (-73.95798 40.73311)     3248.0       2220.0       2464.0
# 3  POINT (-73.95422 40.73190)     3248.0       2220.0       2464.0
# 4  POINT (-73.95548 40.72991)     3248.0       2220.0       2464.0
#
#    num_75k-100k  num_100k-125k  num_125k-150k  num_> 150k
# 0        2206.0         1712.0         1410.0      2963.0
# 1        2206.0         1712.0         1410.0      2963.0
# 2        2206.0         1712.0         1410.0      2963.0
# 3        2206.0         1712.0         1410.0      2963.0
# 4        2206.0         1712.0         1410.0      2963.0

# %%
bkntainc = bkntainc.drop_duplicates('NTACode')
bkntainc.head()
# Out:
#     NTACode                NTAName  Households  pct_0-25k  pct_25k-50k  \
# 0      BK76             Greenpoint       16223   0.200210     0.136843
# 183    BK90      East Williamsburg       16075   0.284044     0.165723
# 348    BK77         Bushwick North       19367   0.290029     0.207415
# 602    BK78         Bushwick South       26616   0.349451     0.207582
# 738    BK73  North Side-South Side       23862   0.192566     0.167337
#
#      pct_50k-75k  pct_75k-100k  pct_100k-125k  pct_125k-150k  pct_> 150k  \
# 0       0.151883      0.135980       0.105529       0.086914    0.182642
# 183     0.123670      0.116579       0.087403       0.065070    0.157512
# 348     0.169515      0.106108       0.084164       0.053441    0.089327
# 602     0.152991      0.101743       0.068643       0.044222    0.075368
# 738     0.113654      0.105859       0.088718       0.070321    0.261546
#
#                        geometry  num_0-25k  num_25k-50k  num_50k-75k  \
# 0    POINT (-73.95497 40.73320)     3248.0       2220.0       2464.0
# 183  POINT (-73.94074 40.72103)     4566.0       2664.0       1988.0
# 348  POINT (-73.93327 40.70759)     5617.0       4017.0       3283.0
# 602  POINT (-73.93723 40.70914)     9301.0       5525.0       4072.0
# 738  POINT (-73.95700 40.72119)     4595.0       3993.0       2712.0
#
#      num_75k-100k  num_100k-125k  num_125k-150k  num_> 150k
# 0          2206.0         1712.0         1410.0      2963.0
# 183        1874.0         1405.0         1046.0      2532.0
# 348        2055.0         1630.0         1035.0      1730.0
# 602        2708.0         1827.0         1177.0      2006.0
# 738        2526.0         2117.0         1678.0      6241.0

# %%
bk_price_inc = bkcounts.merge(bkntainc, how='inner', on='NTACode')
bk_price_inc.head()
# Out:
#   NTACode  price_$  price_$$  price_$$$  price_$$$$  MISSING  \
# 0    BK09       29        46          6           0       16
# 1    BK17       35        54         10           2       21
# 2    BK19       22        17          4           1       14
# 3    BK21       24        12          0           0       14
# 4    BK23        6         4          2           0        4
#
#                                           NTAName  Households  pct_0-25k  \
# 0                    Brooklyn Heights-Cobble Hill       11115   0.115070
# 1  Sheepshead Bay-Gerritsen Beach-Manhattan Beach       26150   0.253805
# 2                                  Brighton Beach       14557   0.395823
# 3                            Seagate-Coney Island       11236   0.478907
# 4                                   West Brighton        8401   0.377217
#
#    pct_25k-50k  ...  pct_125k-150k  pct_> 150k                    geometry  \
# 0     0.108052  ...       0.075574    0.426901  POINT (-73.99231 40.69927)
# 1     0.202600  ...       0.064704    0.127801  POINT (-73.95266 40.57709)
# 2     0.185272  ...       0.035790    0.109569  POINT (-73.96427 40.57672)
# 3     0.203364  ...       0.021360    0.047170  POINT (-73.98381 40.57881)
# 4     0.213070  ...       0.031663    0.063802  POINT (-73.98065 40.57919)
#
#    num_0-25k  num_25k-50k num_50k-75k  num_75k-100k  num_100k-125k  \
# 0     1279.0       1201.0       777.0        1231.0         1042.0
# 1     6637.0       5298.0      3965.0        2832.0         2384.0
# 2     5762.0       2697.0      2311.0         990.0          681.0
# 3     5381.0       2285.0      1447.0         711.0          642.0
# 4     3169.0       1790.0      1250.0         962.0          428.0
#
#    num_125k-150k  num_> 150k
# 0          840.0      4745.0
# 1         1692.0      3342.0
# 2          521.0      1595.0
# 3          240.0       530.0
# 4          266.0       536.0
#
# [5 rows x 23 columns]

# %%
bk_price_inc.shape
# Out:
# (51, 23)

# %%
bk_price_inc.to_csv('BK_YelpPriceFreq_NTAIncDist.csv')
