# %%
import pandas as pd
import numpy as np

# %%
restaurant = pd.read_csv('RestaurantDataWithCensusTracts.csv')
census = pd.read_csv('ACS_17_5YR_B19001_with_ann.csv')

# %%
restaurant.shape
# Out:
# (5947, 27)

# %%
census.shape
# Out:
# (761, 37)

# %%
census['GEOID'] = pd.to_numeric(census['GEOID'], errors='coerce')

# %%
dataset = restaurant.merge(census, on = 'GEOID', how = 'left') #ERIK FIXED THIS

# %%
dataset.shape
# Out:
# (5947, 63)

# %%
dataset.head()
# Out:
#                        id                                    alias  \
# 0  7B7igqEXqfMEgxV1GOBE6A                   the-copperpot-brooklyn
# 1  DI0PHE6PVTpJF6dvG_d1Wg                 red-hook-tavern-brooklyn
# 2  lQKKBtdp7No9HJ_tW6PuAQ                   fort-defiance-brooklyn
# 3  Dsgb9AZAJDPBIAabOAcACA  court-street-grocers-hero-shop-brooklyn
# 4  SSy5YkPo6S8RdCXiJ4EHXw            marks-red-hook-pizza-brooklyn
#
#                              name  is_closed  review_count  rating    price  \
# 0                   The CopperPot      False            34     4.5       $$
# 1                 Red Hook Tavern      False            34     4.5  MISSING
# 2                   Fort Defiance      False           346     4.0       $$
# 3  Court Street Grocers Hero Shop      False            43     4.5       $$
# 4           Mark's Red Hook Pizza      False            55     4.0        $
#
#                      categories   latitude  longitude  ...  \
# ...

# %%
GEOID = dataset.GEOID.unique()

# %%
restaurantbycensus = dataset.groupby(dataset.GEOID).count()

# %%
restaurantbycensus.head()
# Out:
#              Id  Geography  Estimate; Total:  Margin of Error; Total:  \
# GEOID
# 36047000100  20         20                20                       20
# 36047000200  25         25                25                       25
# 36047000301   5          5                 5                        5
# 36047000501  11         11                11                       11
# 36047000502  14         14                14                       14
#
#              Estimate; Total: - Less than $10,000  \
# GEOID
# 36047000100                                    20
# 36047000200                                    25
# 36047000301                                     5
# 36047000501                                    11
# 36047000502                                    14
#
#              Margin of Error; Total: - Less than $10,000  \
# GEOID
# 36047000100                                           20
# 36047000200                                           25
# ...

# %%
restaurant_count = pd.DataFrame(restaurantbycensus['Id'])

# %%
restaurant_count.index[0]
# Out:
# 36047000100

# %%
df1 = dataset[dataset['GEOID'] == restaurant_count.index[0]]

# %%
df1.price.unique()
# Out:
# array(['$$', '$$$', '$', 'MISSING'], dtype=object)
