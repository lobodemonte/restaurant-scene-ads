# %% [markdown]
# This notebook takes the merged Yelp and Census Tract data frame and calculates the frequency of restaurant counts for each price range (including those Missing) for each Census tract.
# Using GEOID (census tract identifier), I merged household income distribution data for each census tract (in percentages), then calculate the actual number of households for each income range.

# %%
# Setting up modules
import geopandas as gpd
from geopandas import GeoDataFrame
import numpy as np
import pandas as pd
from shapely.geometry import Point
import matplotlib.pylab as plt

# Data path 
path = '/Users/andrewnorris/restaurant-scene-ads/'

# %%
bk = gpd.read_file('BK_Yelp_CensusTract.shp')
bk.head()
# Out:
#                        id                   alias           name  is_closed  \
# 0  6gzQLjzJk25ePm_JS7ZAug         esme-brooklyn-2           Esme          0
# 1  utM-5navObsVA5sCRHobzA        madre-brooklyn-2          Madre          0
# 2  J5y7oRfiGtxFDkYGKxFZkw         anella-brooklyn         Anella          0
# 3  _FICyzFLQxR7N62I6qU94A      kanahashi-brooklyn      KanaHashi          0
# 4  z5EpI39omxW6aK_X2uHi8A  lobster-joint-brooklyn  Lobster Joint          0
#
#    review_cou  rating    price                categories   latitude  \
# 0         328     4.5       $$  newamerican|cocktailbars  40.733203
# 1          38     5.0  MISSING               newamerican  40.733110
# 2         408     4.0       $$               newamerican  40.733270
# 3          86     4.5       $$             sushi|lounges  40.732630
# 4         646     4.0       $$                   seafood  40.735400
#
#    longitude  ...                                 Geography Households  0-25k  \
# 0 -73.954967  ...  Census Tract 563, Kings County, New York       2250  0.285
# 1 -73.957980  ...  Census Tract 563, Kings County, New York       2250  0.285
# 2 -73.957860  ...  Census Tract 563, Kings County, New York       2250  0.285
# 3 -73.954820  ...  Census Tract 563, Kings County, New York       2250  0.285
# 4 -73.955280  ...  Census Tract 563, Kings County, New York       2250  0.285
#
#   25k-50k 50k-75k  75k-100k  100k-125k  125k-150k > 150k  \
# 0   0.114    0.13     0.116      0.084      0.084  0.186
# 1   0.114    0.13     0.116      0.084      0.084  0.186
# 2   0.114    0.13     0.116      0.084      0.084  0.186
# 3   0.114    0.13     0.116      0.084      0.084  0.186
# 4   0.114    0.13     0.116      0.084      0.084  0.186
#
#                               geometry
# 0     POINT (-73.95496677 40.73320339)
# 1  POINT (-73.95798000000001 40.73311)
# 2  POINT (-73.95786 40.73327000000001)
# 3           POINT (-73.95482 40.73263)
# 4            POINT (-73.95528 40.7354)
#
# [5 rows x 28 columns]

# %%
bk = pd.DataFrame(bk)

# %%
bk.columns
# Out:
# Index(['id', 'alias', 'name', 'is_closed', 'review_cou', 'rating', 'price',
#        'categories', 'latitude', 'longitude', 'address', 'city', 'zipcode',
#        'state', 'country', 'index_righ', 'GEOID', 'ID_1', 'Geography',
#        'Households', '0-25k', '25k-50k', '50k-75k', '75k-100k', '100k-125k',
#        '125k-150k', '> 150k', 'geometry'],
#       dtype='object')

# %%
bkcounts = pd.DataFrame(bk.groupby(['GEOID', 'price'])['price'].count())

# %%
bkcounts.head(10)
# Out:
#                       price
# GEOID        price
# 3.604700e+10 $            6
#              $$          11
#              $$$          2
#              MISSING      1
#              $            5
#              $$           8
#              MISSING     12
#              $            1
#              $$           4
#              $            1

# %%
bkcounts = bkcounts.unstack(level='price', fill_value=0).reset_index()
bkcounts.head(10)
# Out:
#               GEOID price
# price                   $  $$ $$$ $$$$ MISSING
# 0      3.604700e+10     6  11   2    0       1
# 1      3.604700e+10     5   8   0    0      12
# 2      3.604700e+10     1   4   0    0       0
# 3      3.604700e+10     1   8   0    0       2
# 4      3.604700e+10     5   7   0    0       2
# 5      3.604700e+10     3   6   2    0       2
# 6      3.604700e+10    13  10   2    0       9
# 7      3.604700e+10    23  16   0    0      13
# 8      3.604700e+10     0   3   0    0       1
# 9      3.604700e+10     4  31   1    0      12

# %%
bkcounts.columns = ['_'.join(col) for col in bkcounts.columns]
bkcounts.columns = ['GEOID','price_$', 'price_$$', 'price_$$$', 'price_$$$$','MISSING']
bkcounts.head(10)
# Out:
#           GEOID  price_$  price_$$  price_$$$  price_$$$$  MISSING
# 0  3.604700e+10        6        11          2           0        1
# 1  3.604700e+10        5         8          0           0       12
# 2  3.604700e+10        1         4          0           0        0
# 3  3.604700e+10        1         8          0           0        2
# 4  3.604700e+10        5         7          0           0        2
# 5  3.604700e+10        3         6          2           0        2
# 6  3.604700e+10       13        10          2           0        9
# 7  3.604700e+10       23        16          0           0       13
# 8  3.604700e+10        0         3          0           0        1
# 9  3.604700e+10        4        31          1           0       12

# %%
bk.columns
# Out:
# Index(['id', 'alias', 'name', 'is_closed', 'review_cou', 'rating', 'price',
#        'categories', 'latitude', 'longitude', 'address', 'city', 'zipcode',
#        'state', 'country', 'index_righ', 'GEOID', 'ID_1', 'Geography',
#        'Households', '0-25k', '25k-50k', '50k-75k', '75k-100k', '100k-125k',
#        '125k-150k', '> 150k', 'geometry'],
#       dtype='object')

# %%
bkcounts.GEOID.dtype
# Out:
# dtype('float64')

# %%
bkcounts['GEOID'] = bkcounts['GEOID'].astype(np.int64) #bkinc data frame GEOID is int64 type - change for merging

# %%
bkinc = pd.read_csv(path+'BK_hh_income_dis_count.csv')

# %%
bkinc.head()
# Out:
#             ID                                  Geography  Households  0-25k  \
# 0  36047000100     Census Tract 1, Kings County, New York        2184  0.212
# 1  36047000200     Census Tract 2, Kings County, New York         377  0.263
# 2  36047000301  Census Tract 3.01, Kings County, New York        1865  0.043
# 3  36047000501  Census Tract 5.01, Kings County, New York        1772  0.188
# 4  36047000502  Census Tract 5.02, Kings County, New York        1560  0.132
#
#    25k-50k  50k-75k  75k-100k  100k-125k  125k-150k  > 150k
# 0    0.099    0.087     0.184      0.066      0.070   0.281
# 1    0.305    0.207     0.069      0.125      0.000   0.032
# 2    0.205    0.009     0.107      0.124      0.076   0.435
# 3    0.042    0.094     0.056      0.095      0.117   0.407
# 4    0.115    0.074     0.107      0.099      0.072   0.399

# %%
bkinc = bkinc.rename(columns={'ID':'GEOID'})

# %%
bk_price_inc = bkcounts.merge(bkinc, how='inner', on='GEOID')

# %%
bk_price_inc.head(10)
# Out:
#          GEOID  price_$  price_$$  price_$$$  price_$$$$  MISSING  \
# 0  36047000100        6        11          2           0        1
# 1  36047000200        5         8          0           0       12
# 2  36047000301        1         4          0           0        0
# 3  36047000501        1         8          0           0        2
# 4  36047000502        5         7          0           0        2
# 5  36047000700        3         6          2           0        2
# 6  36047000900       13        10          2           0        9
# 7  36047001100       23        16          0           0       13
# 8  36047001300        0         3          0           0        1
# 9  36047001500        4        31          1           0       12
#
#                                    Geography  Households  0-25k  25k-50k  \
# 0     Census Tract 1, Kings County, New York        2184  0.212    0.099
# 1     Census Tract 2, Kings County, New York         377  0.263    0.305
# 2  Census Tract 3.01, Kings County, New York        1865  0.043    0.205
# 3  Census Tract 5.01, Kings County, New York        1772  0.188    0.042
# 4  Census Tract 5.02, Kings County, New York        1560  0.132    0.115
# 5     Census Tract 7, Kings County, New York        1781  0.070    0.089
# 6     Census Tract 9, Kings County, New York        1953  0.036    0.097
# 7    Census Tract 11, Kings County, New York         655  0.096    0.015
# 8    Census Tract 13, Kings County, New York         914  0.061    0.171
# 9    Census Tract 15, Kings County, New York        3185  0.208    0.122
#
#    50k-75k  75k-100k  100k-125k  125k-150k  > 150k
# 0    0.087     0.184      0.066      0.070   0.281
# 1    0.207     0.069      0.125      0.000   0.032
# 2    0.009     0.107      0.124      0.076   0.435
# 3    0.094     0.056      0.095      0.117   0.407
# 4    0.074     0.107      0.099      0.072   0.399
# 5    0.076     0.072      0.079      0.084   0.531
# 6    0.078     0.120      0.102      0.038   0.527
# 7    0.067     0.145      0.154      0.087   0.435
# 8    0.109     0.089      0.128      0.106   0.336
# 9    0.085     0.076      0.113      0.080   0.314

# %%
bk_price_inc = bk_price_inc.rename(columns={"0-25k": "pct_0-25k", "25k-50k": "pct_25k-50k", '50k-75k':'pct_50k-75k', \
                                           '75k-100k':'pct_75k-100k', '100k-125k':'pct_100k-125k', '125k-150k':'pct_125k-150k',\
                                           '> 150k':'pct_> 150k'})

# %%
bk_price_inc['num_0-25k'] = bk_price_inc['Households']*bk_price_inc['pct_0-25k']
bk_price_inc['num_25k-50k'] = bk_price_inc['Households']*bk_price_inc['pct_25k-50k']
bk_price_inc['num_50k-75k'] = bk_price_inc['Households']*bk_price_inc['pct_50k-75k']
bk_price_inc['num_75k-100k'] = bk_price_inc['Households']*bk_price_inc['pct_75k-100k']
bk_price_inc['num_100k-125k'] = bk_price_inc['Households']*bk_price_inc['pct_100k-125k']
bk_price_inc['num_125k-150k'] = bk_price_inc['Households']*bk_price_inc['pct_125k-150k']
bk_price_inc['num_> 150k'] = bk_price_inc['Households']*bk_price_inc['pct_> 150k']

# %%
bk_price_inc.head()
# Out:
#          GEOID  price_$  price_$$  price_$$$  price_$$$$  MISSING  \
# 0  36047000100        6        11          2           0        1
# 1  36047000200        5         8          0           0       12
# 2  36047000301        1         4          0           0        0
# 3  36047000501        1         8          0           0        2
# 4  36047000502        5         7          0           0        2
#
#                                    Geography  Households  pct_0-25k  \
# 0     Census Tract 1, Kings County, New York        2184      0.212
# 1     Census Tract 2, Kings County, New York         377      0.263
# 2  Census Tract 3.01, Kings County, New York        1865      0.043
# 3  Census Tract 5.01, Kings County, New York        1772      0.188
# 4  Census Tract 5.02, Kings County, New York        1560      0.132
#
#    pct_25k-50k  ...  pct_100k-125k  pct_125k-150k  pct_> 150k  num_0-25k  \
# 0        0.099  ...          0.066          0.070       0.281    463.008
# 1        0.305  ...          0.125          0.000       0.032     99.151
# 2        0.205  ...          0.124          0.076       0.435     80.195
# 3        0.042  ...          0.095          0.117       0.407    333.136
# 4        0.115  ...          0.099          0.072       0.399    205.920
#
#    num_25k-50k  num_50k-75k  num_75k-100k  num_100k-125k  num_125k-150k  \
# 0      216.216      190.008       401.856        144.144        152.880
# 1      114.985       78.039        26.013         47.125          0.000
# 2      382.325       16.785       199.555        231.260        141.740
# 3       74.424      166.568        99.232        168.340        207.324
# 4      179.400      115.440       166.920        154.440        112.320
#
#    num_> 150k
# 0     613.704
# 1      12.064
# 2     811.275
# 3     721.204
# 4     622.440
#
# [5 rows x 22 columns]

# %%
bk_price_inc.shape
# Out:
# (634, 22)

# %%
bk_price_inc.to_csv('BK_incdist_pricefreq.csv')
